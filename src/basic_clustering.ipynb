# %%
import pandas as pd
df = pd.read_csv("../data/examples_DBAASP/descriptors_positive_staphylococcus.csv")

# %%
# KMeans clustering

from sklearn import metrics
from sklearn.cluster import KMeans

silhouette_scores = []
for i in range(2, 100):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(df)
    score = metrics.silhouette_score(df, kmeans.labels_, metric='euclidean')
    silhouette_scores.append(score)
    print(f"Silhouette score for {i} clusters: {score}")
# Out:
# Silhouette score for 2 clusters: 0.2874496834189739
# Silhouette score for 3 clusters: 0.2684807427439397
# Silhouette score for 4 clusters: 0.2860758083529523
# Silhouette score for 5 clusters: 0.24784861780434275
# Silhouette score for 6 clusters: 0.22855950949823248
# Silhouette score for 7 clusters: 0.2277256616732287
# Silhouette score for 8 clusters: 0.22870228317452757
# Silhouette score for 9 clusters: 0.23001632540925263
# Silhouette score for 10 clusters: 0.22192721440573093
# Silhouette score for 11 clusters: 0.22293635555450092
# Silhouette score for 12 clusters: 0.2319117545534162
# Silhouette score for 13 clusters: 0.2298008445922457
# Silhouette score for 14 clusters: 0.2290592094223039
# Silhouette score for 15 clusters: 0.23460160645761616
# Silhouette score for 16 clusters: 0.2380718977567005
# Silhouette score for 17 clusters: 0.23508551469605551
# Silhouette score for 18 clusters: 0.23788984853178144
# Silhouette score for 19 clusters: 0.22845978605732908
# Silhouette score for 20 clusters: 0.2295677040448418
# Silhouette score for 21 clusters: 0.22944742174576885
# Silhouette score for 22 clusters: 0.22402907767558908
# Silhouette score for 23 clusters: 0.2277716843060583
# Silhouette score for 24 clusters: 0.21707065030864497
# Silhouette score for 25 clusters: 0.20947640364053507
# Silhouette score for 26 clusters: 0.20901618257358953
# Silhouette score for 27 clusters: 0.211763907831302
# Silhouette score for 28 clusters: 0.21617555579933775
# Silhouette score for 29 clusters: 0.2155721203123413
# Silhouette score for 30 clusters: 0.2218075813793727
# Silhouette score for 31 clusters: 0.22094214160943715
# Silhouette score for 32 clusters: 0.21873629739490089
# Silhouette score for 33 clusters: 0.2039285003610182
# Silhouette score for 34 clusters: 0.20772855912047886
# Silhouette score for 35 clusters: 0.20926680527363947
# Silhouette score for 36 clusters: 0.2189172343783803
# Silhouette score for 37 clusters: 0.22320501896762304
# Silhouette score for 38 clusters: 0.22283797393576169
# Silhouette score for 39 clusters: 0.21945335484349013
# Silhouette score for 40 clusters: 0.21835374250119655
# Silhouette score for 41 clusters: 0.22216926709513746
# Silhouette score for 42 clusters: 0.22128163054507513
# Silhouette score for 43 clusters: 0.21826442364864523
# Silhouette score for 44 clusters: 0.2205463059899446
# Silhouette score for 45 clusters: 0.22147505370574125
# Silhouette score for 46 clusters: 0.22117606437256754
# Silhouette score for 47 clusters: 0.21941081578938146
# Silhouette score for 48 clusters: 0.21454731165452767
# Silhouette score for 49 clusters: 0.21562630517449
# Silhouette score for 50 clusters: 0.21761323026778098
# Silhouette score for 51 clusters: 0.2208258917264115
# Silhouette score for 52 clusters: 0.21986632801428513
# Silhouette score for 53 clusters: 0.22125081662853516
# Silhouette score for 54 clusters: 0.22304847620056673
# Silhouette score for 55 clusters: 0.23257120078070423
# Silhouette score for 56 clusters: 0.23239717586022307
# Silhouette score for 57 clusters: 0.2328204791574488
# Silhouette score for 58 clusters: 0.23442769385718568
# Silhouette score for 59 clusters: 0.23441473638807023
# Silhouette score for 60 clusters: 0.23465121702584013
# Silhouette score for 61 clusters: 0.23480478450919495
# Silhouette score for 62 clusters: 0.2345490248770158
# Silhouette score for 63 clusters: 0.23403293038881945
# Silhouette score for 64 clusters: 0.23218852595592276
# Silhouette score for 65 clusters: 0.23261505647018704
# Silhouette score for 66 clusters: 0.23115636599672887
# Silhouette score for 67 clusters: 0.23294006312220472
# Silhouette score for 68 clusters: 0.22694896103978787
# Silhouette score for 69 clusters: 0.22743967509053106
# Silhouette score for 70 clusters: 0.2280035207213835
# Silhouette score for 71 clusters: 0.22570332850271005
# Silhouette score for 72 clusters: 0.22668937319117896
# Silhouette score for 73 clusters: 0.2302983109258972
# Silhouette score for 74 clusters: 0.2293787257103818
# Silhouette score for 75 clusters: 0.22890119594046335
# Silhouette score for 76 clusters: 0.2297651398100677
# Silhouette score for 77 clusters: 0.2314722085122145
# Silhouette score for 78 clusters: 0.23165554448501288
# Silhouette score for 79 clusters: 0.23051907579534744
# Silhouette score for 80 clusters: 0.23162923871384358
# Silhouette score for 81 clusters: 0.229152516698445
# Silhouette score for 82 clusters: 0.23169750935760486
# Silhouette score for 83 clusters: 0.233959843965578
# Silhouette score for 84 clusters: 0.23357868951469232
# Silhouette score for 85 clusters: 0.23494982372079565
# Silhouette score for 86 clusters: 0.2321173852033646
# Silhouette score for 87 clusters: 0.23193266861990022
# Silhouette score for 88 clusters: 0.2320431168093399
# Silhouette score for 89 clusters: 0.23442620970385644
# Silhouette score for 90 clusters: 0.2299368029988543
# Silhouette score for 91 clusters: 0.23063392649945977
# Silhouette score for 92 clusters: 0.22915685611046488
# Silhouette score for 93 clusters: 0.2343309510944019
# Silhouette score for 94 clusters: 0.23632403802179885
# Silhouette score for 95 clusters: 0.2385635001396728
# Silhouette score for 96 clusters: 0.23985632779611232
# Silhouette score for 97 clusters: 0.23611852506954234
# Silhouette score for 98 clusters: 0.23642856077798463
# Silhouette score for 99 clusters: 0.23493609053583636

# %%
# Agglomerative clustering

from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering

silhouette_scores = []
for i in range(2, 100):
    agg = AgglomerativeClustering(n_clusters=i).fit(df)
    score = metrics.silhouette_score(df, agg.labels_, metric='euclidean')
    silhouette_scores.append(score)
    print(f"Silhouette score for {i} clusters: {score}")
# Out:
# Silhouette score for 2 clusters: 0.20961377050781768
# Silhouette score for 3 clusters: 0.21669325987340118
# Silhouette score for 4 clusters: 0.21680291396996124
# Silhouette score for 5 clusters: 0.2360666702447631
# Silhouette score for 6 clusters: 0.20677918845802232
# Silhouette score for 7 clusters: 0.1893930932365249
# Silhouette score for 8 clusters: 0.19897532199029783
# Silhouette score for 9 clusters: 0.20407146032318133
# Silhouette score for 10 clusters: 0.20894739660047615
# Silhouette score for 11 clusters: 0.20232589641610071
# Silhouette score for 12 clusters: 0.20450223276799515
# Silhouette score for 13 clusters: 0.20796761212822157
# Silhouette score for 14 clusters: 0.19749418108013236
# Silhouette score for 15 clusters: 0.18714508254889106
# Silhouette score for 16 clusters: 0.19149519656013536
# Silhouette score for 17 clusters: 0.18607867130640884
# Silhouette score for 18 clusters: 0.1919558806449183
# Silhouette score for 19 clusters: 0.197284261018388
# Silhouette score for 20 clusters: 0.19312889574858375
# Silhouette score for 21 clusters: 0.19674589280463692
# Silhouette score for 22 clusters: 0.19407945672517599
# Silhouette score for 23 clusters: 0.19955192122736665
# Silhouette score for 24 clusters: 0.20496869123070355
# Silhouette score for 25 clusters: 0.2074178723427897
# Silhouette score for 26 clusters: 0.2109523785505969
# Silhouette score for 27 clusters: 0.2130353986032561
# Silhouette score for 28 clusters: 0.21537453996838377
# Silhouette score for 29 clusters: 0.2155986550620669
# Silhouette score for 30 clusters: 0.20961723412464497
# Silhouette score for 31 clusters: 0.19942204772656405
# Silhouette score for 32 clusters: 0.2019628668595344
# Silhouette score for 33 clusters: 0.2021740139766983
# Silhouette score for 34 clusters: 0.20514021522241718
# Silhouette score for 35 clusters: 0.2077458749553702
# Silhouette score for 36 clusters: 0.20714615187417482
# Silhouette score for 37 clusters: 0.20606420995591734
# Silhouette score for 38 clusters: 0.20737860817493584
# Silhouette score for 39 clusters: 0.20097112908994827
# Silhouette score for 40 clusters: 0.20287922883261886
# Silhouette score for 41 clusters: 0.19844107241005055
# Silhouette score for 42 clusters: 0.20271640573635138
# Silhouette score for 43 clusters: 0.2053052230522671
# Silhouette score for 44 clusters: 0.20610535882815517
# Silhouette score for 45 clusters: 0.20742307676753327
# Silhouette score for 46 clusters: 0.20825284990797285
# Silhouette score for 47 clusters: 0.21205939157308598
# Silhouette score for 48 clusters: 0.20657684408144036
# Silhouette score for 49 clusters: 0.20856089002699313
# Silhouette score for 50 clusters: 0.20788673021358692
# Silhouette score for 51 clusters: 0.2101319242009884
# Silhouette score for 52 clusters: 0.2093484894867527
# Silhouette score for 53 clusters: 0.21132492975035821
# Silhouette score for 54 clusters: 0.2138190106042314
# Silhouette score for 55 clusters: 0.215893744457186
# Silhouette score for 56 clusters: 0.21693544908029175
# Silhouette score for 57 clusters: 0.22059054291999108
# Silhouette score for 58 clusters: 0.22212466629272518
# Silhouette score for 59 clusters: 0.22494940788972262
# Silhouette score for 60 clusters: 0.22672748736807985
# Silhouette score for 61 clusters: 0.22584434980804907
# Silhouette score for 62 clusters: 0.2260438405781271
# Silhouette score for 63 clusters: 0.2279420028074521
# Silhouette score for 64 clusters: 0.2275479495772269
# Silhouette score for 65 clusters: 0.22740038365571313
# Silhouette score for 66 clusters: 0.22938759592711705
# Silhouette score for 67 clusters: 0.23111947623411228
# Silhouette score for 68 clusters: 0.23186057479874023
# Silhouette score for 69 clusters: 0.2325208879855548
# Silhouette score for 70 clusters: 0.23399661485844578
# Silhouette score for 71 clusters: 0.2356995530670642
# Silhouette score for 72 clusters: 0.2368514229477133
# Silhouette score for 73 clusters: 0.23576448622005378
# Silhouette score for 74 clusters: 0.2343036741690098
# Silhouette score for 75 clusters: 0.23485900840470253
# Silhouette score for 76 clusters: 0.23610086621944787
# Silhouette score for 77 clusters: 0.2354545089972984
# Silhouette score for 78 clusters: 0.23583166292061675
# Silhouette score for 79 clusters: 0.2356788432214609
# Silhouette score for 80 clusters: 0.236080172667819
# Silhouette score for 81 clusters: 0.23717686749589106
# Silhouette score for 82 clusters: 0.2396600877256827
# Silhouette score for 83 clusters: 0.23944703411266863
# Silhouette score for 84 clusters: 0.24105640991963315
# Silhouette score for 85 clusters: 0.2403215025850575
# Silhouette score for 86 clusters: 0.24044966915561855
# Silhouette score for 87 clusters: 0.23983430795555674
# Silhouette score for 88 clusters: 0.24000026167976682
# Silhouette score for 89 clusters: 0.24012313126279802
# Silhouette score for 90 clusters: 0.23822939739078777
# Silhouette score for 91 clusters: 0.23919715407171802
# Silhouette score for 92 clusters: 0.2363644085007008
# Silhouette score for 93 clusters: 0.23498107013878594
# Silhouette score for 94 clusters: 0.2356716780568405
# Silhouette score for 95 clusters: 0.2358726394428442
# Silhouette score for 96 clusters: 0.23599668834168794
# Silhouette score for 97 clusters: 0.23592694283350166
# Silhouette score for 98 clusters: 0.23671477648394917
# Silhouette score for 99 clusters: 0.236379221225221

# %%
# dendrogram visualization - hierarchical clustering
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.title("Dendogram")
dend = shc.dendrogram(shc.linkage(df, method='ward'))

plt.show()

# %%
# TSNE visualization

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, random_state=0)
df_tsne = tsne.fit_transform(df)
plt.scatter(df_tsne[:, 0], df_tsne[:, 1])
plt.show()
